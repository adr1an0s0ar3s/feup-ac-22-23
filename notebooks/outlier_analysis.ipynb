# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/unified_data.csv')

# %%
df
# Out:
#     ownerSex  ownerBirthday ownerCardType                   frequency  \
# 0       male         450204           NaN            monthly issuance
# 1     female         390423           NaN            monthly issuance
# 2     female         440613           NaN            monthly issuance
# 3     female         450703           NaN  issuance after transaction
# 4       male         391130           NaN            monthly issuance
# ..       ...            ...           ...                         ...
# 323   female         801113           NaN            monthly issuance
# 324     male         730216           NaN            monthly issuance
# 325   female         451030           NaN             weekly issuance
# 326     male         680413       classic            monthly issuance
# 327   female         621019           NaN            monthly issuance
#
#      accountCreationDate  isShared  balance  loanDate  loanDuration  \
# 0                 930226         1  27847.9    940105            24
# 1                 950407         0  15854.0    960429            12
# 2                 941019         0  23696.5    960502            24
# 3                 960511         1  78957.6    961106            12
# 4                 931126         1  28015.4    940531            12
# ..                   ...       ...      ...       ...           ...
# 323               941124         1  53252.4    961002            60
# 324               930114         0  21029.0    930915            12
# 325               950526         1  24704.4    951029            60
# 326               941001         0  25689.9    960806            12
# 327               951014         0  24199.5    961227            24
#
#      loanPayments  ...  nMunicipalitiesOver10000Inhabitants  nCities  \
# 0            3373  ...                                    1        1
# 1            2523  ...                                    1        7
# 2            6915  ...                                    1        8
# 3            7370  ...                                    3        8
# 4            8734  ...                                    3        5
# ..            ...  ...                                  ...      ...
# 323          6541  ...                                    1        6
# 324          4399  ...                                    1        5
# 325          6998  ...                                    1        1
# 326          4502  ...                                    1        6
# 327          5392  ...                                    2        6
#
#     urbanInhabitantsRatio averageSalary  unemploymentRate95  \
# 0                   100.0         12541                0.29
# 1                    67.0          9104                1.51
# 2                    56.9          8427                1.12
# 3                    85.3          9317                6.49
# 4                    48.3          8512                3.51
# ..                    ...           ...                 ...
# 323                  58.0          8754                3.83
# 324                  51.9          9045                3.13
# 325                 100.0         12541                0.29
# 326                  53.8          8814                4.76
# 327                  63.1          8110                5.77
#
#      unemploymentRate96  nEnterpreneursPer1000Inhabitants  commitedCrimes95  \
# 0                  0.43                               167             85677
# 1                  2.07                               123              2299
# 2                  1.54                               107              1874
# 3                  7.07                                97              6949
# 4                  4.12                               102              2247
# ..                  ...                               ...               ...
# 323                4.31                               137              3804
# 324                3.60                               124              1845
# 325                0.43                               167             85677
# 326                5.74                               107              2112
# 327                6.55                               109              3244
#
#      commitedCrimes96  status
# 0               99107       0
# 1                2354       1
# 2                1913       0
# 3                6872       0
# 4                2103       0
# ..                ...     ...
# 323              3868       0
# 324              1879       0
# 325             99107       0
# 326              2059       0
# 327              3079       0
#
# [328 rows x 28 columns]

# %%
df.dtypes
# Out:
# ownerSex                                 object
# ownerBirthday                             int64
# ownerCardType                            object
# frequency                                object
# accountCreationDate                       int64
# isShared                                  int64
# balance                                 float64
# loanDate                                  int64
# loanDuration                              int64
# loanPayments                              int64
# loanAmount                                int64
# ratio                                   float64
# districtName                             object
# region                                   object
# nInhabitants                              int64
# nMunicipalitiesSub499Inhabitants          int64
# nMunicipalities500to1999Inhabitants       int64
# nMunicipalities2000to9999Inhabitants      int64
# nMunicipalitiesOver10000Inhabitants       int64
# nCities                                   int64
# urbanInhabitantsRatio                   float64
# averageSalary                             int64
# unemploymentRate95                       object
# unemploymentRate96                      float64
# nEnterpreneursPer1000Inhabitants          int64
# commitedCrimes95                         object
# commitedCrimes96                          int64
# status                                    int64
# dtype: object

# %%
df['commitedCrimes95']
# Out:
# 0      85677
# 1       2299
# 2       1874
# 3       6949
# 4       2247
#        ...
# 323     3804
# 324     1845
# 325    85677
# 326     2112
# 327     3244
# Name: commitedCrimes95, Length: 328, dtype: object

# %%
result = pd.to_numeric(df['commitedCrimes95'], errors='coerce')
df[result.isna()]
# Out:
#     ownerSex  ownerBirthday ownerCardType                   frequency  \
# 13      male         570217           NaN            monthly issuance
# 32    female         690313           NaN  issuance after transaction
# 217   female         500302           NaN             weekly issuance
#
#      accountCreationDate  isShared  balance  loanDate  loanDuration  \
# 13                950613         0   8640.6    960411            48
# 32                941117         0  38697.3    960824            48
# 217               960609         0  54740.9    960922            24
#
#      loanPayments  ...  nMunicipalitiesOver10000Inhabitants  nCities  \
# 13           4492  ...                                    1        3
# 32           8094  ...                                    1        3
# 217          3505  ...                                    1        3
#
#     urbanInhabitantsRatio averageSalary  unemploymentRate95  \
# 13                   48.4          8173                   ?
# 32                   48.4          8173                   ?
# 217                  48.4          8173                   ?
#
#      unemploymentRate96  nEnterpreneursPer1000Inhabitants  commitedCrimes95  \
# 13                 7.01                               124                 ?
# 32                 7.01                               124                 ?
# 217                7.01                               124                 ?
#
#      commitedCrimes96  status
# 13               1358       1
# 32               1358       1
# 217              1358       0
#
# [3 rows x 28 columns]

# %%
df.dtypes
# Out:
# ownerSex                                 object
# ownerBirthday                             int64
# ownerCardType                            object
# frequency                                object
# accountCreationDate                       int64
# isShared                                  int64
# balance                                 float64
# loanDate                                  int64
# loanDuration                              int64
# loanPayments                              int64
# loanAmount                                int64
# ratio                                   float64
# districtName                             object
# region                                   object
# nInhabitants                              int64
# nMunicipalitiesSub499Inhabitants          int64
# nMunicipalities500to1999Inhabitants       int64
# nMunicipalities2000to9999Inhabitants      int64
# nMunicipalitiesOver10000Inhabitants       int64
# nCities                                   int64
# urbanInhabitantsRatio                   float64
# averageSalary                             int64
# unemploymentRate95                       object
# unemploymentRate96                      float64
# nEnterpreneursPer1000Inhabitants          int64
# commitedCrimes96                          int64
# status                                    int64
# commitedCrimes95                          int64
# dtype: object

# %%
normalized_df = (df - df.mean(numeric_only=True)) / df.std(numeric_only=True)

# %%
plot = sns.boxplot(data=normalized_df)
plot.axes.tick_params(axis='x', rotation=90)
plt.savefig('boxplot.png')
# Out:
# /home/adria/Documents/repos/feup-ac-22-23/venv/lib/python3.10/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# Attributes with outliers:
# - averageSalary
# - commitedCrimes95/96
# - loanAmount
# - loanDate (?)
# - nEnterpreneursPer1000Inhabitants
# - nInhabitants
# - nMunicipalities > won't be looked at
# - OwnerBirthday (wtf is going on here)
# - unemploymentRate96

# %%
for a in ['averageSalary', 'commitedCrimes96', 'loanAmount', 'loanDate', 'nEnterpreneursPer1000Inhabitants','nInhabitants','ownerBirthday', 'unemploymentRate96']:
    sns.boxplot(data=df, y=a)
    plt.show()
