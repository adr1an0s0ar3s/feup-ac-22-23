# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/unified_data.csv')

# %%
normalized_df = normalized_df=(df-df.mean())/df.std()
# Out:
# /tmp/ipykernel_15659/846068758.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   normalized_df = normalized_df=(df-df.mean())/df.std()
# /tmp/ipykernel_15659/846068758.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   normalized_df = normalized_df=(df-df.mean())/df.std()

# %%
plot = sns.boxplot(data=normalized_df)
plot.axes.tick_params(axis='x', rotation=90)
plt.savefig('boxplot.png')
# Out:
# /home/filipe/.local/lib/python3.10/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# Attributes with outliers:
# - averageSalary
# - commitedCrimes95/96
# - loanAmount
# - loanDate (?)
# - nEnterpreneursPer1000Inhabitants
# - nInhabitants
# - nMunicipalities > won't be looked at
# - OwnerBirthday (wtf is going on here)
# - unemploymentRate96

# %%
for a in ['averageSalary', 'commitedCrimes95', 'commitedCrimes96', 'loanAmount', 'loanDate', 'nEnterpreneursPer1000Inhabitants','nInhabitants','ownerBirthday', 'unemploymentRate96']:
    sns.boxplot(data=df, y=a)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 for a in ['averageSalary', 'commitedCrimes95', 'commitedCrimes96', 'loanAmount', 'loanDate', 'nEnterpreneursPer1000Inhabitants','nInhabitants','ownerBirthday', 'unemploymentRate96']:
# ----> 2     sns.boxplot(data=df, y=a)
#       3     plt.show()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:2230, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2223 def boxplot(
#    2224     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2225     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2226     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2227     **kwargs
#    2228 ):
# ...
