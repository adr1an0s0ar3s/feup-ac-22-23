# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/unified_data.csv')

# %%
df.head(500)
# Out:
#     ownerSex  ownerBirthday ownerCardType                   frequency  \
# 0       male         450204           NaN            monthly issuance
# 1     female         390423           NaN            monthly issuance
# 2     female         440613           NaN            monthly issuance
# 3     female         450703           NaN  issuance after transaction
# 4       male         391130           NaN            monthly issuance
# ..       ...            ...           ...                         ...
# 323   female         801113           NaN            monthly issuance
# 324     male         730216           NaN            monthly issuance
# 325   female         451030           NaN             weekly issuance
# 326     male         680413       classic            monthly issuance
# 327   female         621019           NaN            monthly issuance
#
#      accountCreationDate  isShared  balance  loanDate  loanDuration  \
# ...

# %%
df.isna().any()
# Out:
# ownerSex                                False
# ownerBirthday                           False
# ownerCardType                            True
# frequency                               False
# accountCreationDate                     False
# isShared                                False
# balance                                 False
# loanDate                                False
# loanDuration                            False
# loanPayments                            False
# loanAmount                              False
# ratio                                   False
# districtName                            False
# region                                  False
# nInhabitants                            False
# nMunicipalitiesSub499Inhabitants        False
# nMunicipalities500to1999Inhabitants     False
# nMunicipalities2000to9999Inhabitants    False
# nMunicipalitiesOver10000Inhabitants     False
# nCities                                 False
# ...

# %%
df['balance']
# Out:
# 0      27847.9
# 1      15854.0
# 2      23696.5
# 3      78957.6
# 4      28015.4
#         ...
# 323    53252.4
# 324    21029.0
# 325    24704.4
# 326    25689.9
# 327    24199.5
# Name: balance, Length: 328, dtype: float64
